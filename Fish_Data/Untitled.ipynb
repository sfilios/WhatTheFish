# %%
import base64

# %%
#get the image files
image = "../SCUP.jpg"
encoded_image = base64.b64encode(open(image, 'rb').read())

# %%
# !ls ../fish_pics
# Out:
# ATLANTIC_CROAKER.jpg   DOLPHIN.jpg	     SPOTTED_SEATROUT.jpg
# ATLANTIC_MACKEREL.jpg  GRAY_SNAPPER.jpg      SUMMER_FLOUNDER.jpg
# BLACK_SEA_BASS.jpg     SCUP.jpg
# BLUEFISH.jpg	       SPANISH_MACKEREL.jpg

# %%
encoded_image
# Out:
# b'...'
